# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 10</b></center>
# <center><b><h1>¥@$# Kakadiya | 23010101121 | 11-02-2025</b></center>
# <pre>

# %% [markdown]
# # Exception Handling

# %% [markdown]
# ### 01) WAP to handle following exceptions:
# 1. ZeroDivisionError
# 2. ValueError
# 3. TypeError
# #### Note: handle them using separate except blocks and also using single except block too.

# %%
try:
    a = 10
    b = 0
    c = a / b
    print(c)
except ZeroDivisionError:
    print("Error: Division by Zero")

try:
    a = int("frds")
    print(a)
except ValueError:
    print("Error: Invalid Input")

try:
    a = 10
    b = "v"
    c = a / b
    print(c)
except TypeError:
    print("Error: Invalid Data Type")
# Out:
# Error: Division by Zero
# Error: Invalid Input
# Error: Invalid Data Type

# %% [markdown]
# ### 02)  WAP to handle following exceptions:
# 1. IndexError
# 2. KeyError

# %%
try:
    lst = [1, 2, 3, 4]
    print(lst[5])

except IndexError:
    print("Error: Index out of range")

try:
    dict = {"1": 1, "2": 2, "3": 3}
    print(dict["5"])

except KeyError:
    print("Error: Key not found")
# Out:
# Error: Index out of range
# Error: Key not found

# %% [markdown]
# ### 03) WAP to handle following exceptions:
# 1. FileNotFoundError
# 2. ModuleNotFoundError

# %%
try:
    file = open("python.txt", "r")
    print(file.read())
except FileNotFoundError:
    print("The file does not exist.")


try:
    import pythonmodule

    print("Module imported successfully.")

except ModuleNotFoundError:
    print("The module does not exist.")
# Out:
# The file does not exist.
# The module does not exist.

# %% [markdown]
# ### 04) WAP that catches all type of exceptions in a single except block.

# %%
try:
    a = 10
    b = "v"
    c = a / b
    print(c)
    print("Division completed successfully.")
    a = 10
    b = 0
    c = a / b
    print(c)
    print("Division completed successfully.")
    a = int("frds")
    print(a)
    lst = [1, 2, 3, 4]
    print(lst[5])
    dict = {"1": 1, "2": 2, "3": 3}
    print(dict["5"])
    file = open("python.txt", "r")
    print(file.read())
    import pythonmodule

    print("Module imported successfully.")

    file = open("python.txt", "r")
    print(file.read())
    print("File opened successfully.")


except Exception as e:
    print("An error occurred:", e)
# Out:
# An error occurred: unsupported operand type(s) for /: 'int' and 'str'

# %% [markdown]
# ### 05) WAP to demonstrate else  and finally block.

# %%
try:
    a = 10
    b = 0
    c = a / b
    print(c)
    print("Division completed successfully.")

except ZeroDivisionError:
    print("Error: Division by Zero")
else:
    print("Else block executed.", c)
finally:
    print("Finally block executed.")
# Out:
# Error: Division by Zero
# Finally block executed.

# %% [markdown]
# ### 06) Create a short program that prompts the user for a list of grades separated by commas.
# ### Split the string into individual grades and use a list comprehension to convert each string to an integer.
# ### You should use a try statement to inform the user when the values they entered cannot be converted.

# %%
print("Enter a list of grades separated by commas:")
print("For example: 85,90,78,92")
grades = input()
print("You entered:", grades)
print("-"*50)

grades = grades.split(",")
print("Split grades:", grades)
try:
    grades = [int(grade) for grade in grades]
    print("Converted grades to integers:")
    print(grades)
    total = sum(grades)
    print("Total of grades:", total)

except ValueError:
    print("Error: Invalid Input")
# Out:
# Enter a list of grades separated by commas:
# For example: 85,90,78,92
# You entered: 85,90,78,92.
# --------------------------------------------------
# Split grades: ['85', '90', '78', '92.']
# Error: Invalid Input

# %% [markdown]
# ### 07) WAP to create an udf divide(a,b) that handles ZeroDivisionError.

# %%
def divide(a, b):
    try:
        return a / b
    except ZeroDivisionError:
        return "Error: Division by zero is not allowed"


print(divide(4, 2))

print(divide(2, 0))
# Out:
# 2.0
# Error: Division by zero is not allowed

# %% [markdown]
# ### 08) WAP that gets an age of a person form the user and raises ValueError with error message: "Enter Valid Age" :
# #### If the age is less than 18.
# #### otherwise print the age.

# %%
try:

    def getage(a):
        if a < 18:
            raise ValueError("Enter Valid Age")
        else:
            print("Age:", a)

finally:
    print("Finally block executed.")

getage(34)
getage(17)
# Out:
# Finally block executed.
# Age: 34
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 13
#      10     print("Finally block executed.")
#      12 getage(34)
# ---> 13 getage(17)
#
# Cell In[19], line 5, in getage(a)
#       3 def getage(a):
#       4     if a < 18:
# ----> 5         raise ValueError("Enter Valid Age")
#       6     else:
#       7         print("Age:", a)
#
# ValueError: Enter Valid Age

# %% [markdown]
# ### 09) WAP to raise your custom Exception named InvalidUsernameError with the error message : "Username must be between 5 and 15 characters long":
# #### if the given name is having characters less than 5 or greater than 15.
# #### otherwise print the given username.

# %%
class InvalidUsernameError(Exception):
    def __init__(self, message):
        super().__init__(message)


def validate_username(username):
    if len(username) < 5 or len(username) > 15:
        raise InvalidUsernameError("Username must be between 5 and 15 characters long.")
    else:
        print("Username:", username)


validate_username("¥@$#")
# Out:
# ---------------------------------------------------------------------------
# InvalidUsernameError                      Traceback (most recent call last)
# Cell In[20], line 13
#       9     else:
#      10         print("Username:", username)
# ---> 13 validate_username("¥@$#")
#
# Cell In[20], line 8, in validate_username(username)
#       6 def validate_username(username):
#       7     if len(username) < 5 or len(username) > 15:
# ----> 8         raise InvalidUsernameError("Username must be between 5 and 15 characters long.")
#       9     else:
#      10         print("Username:", username)
#
# InvalidUsernameError: Username must be between 5 and 15 characters long.

# %% [markdown]
# ### 10) WAP to raise your custom Exception named NegativeNumberError with the error message : "Cannot calculate the square root of a negative number" :
# #### if the given number is negative.
# #### otherwise print the square root of the given number.

# %%
class NegativeNumberError(Exception):
    def __init__(self, message):
        super().__init__(message)


def root(number):
    if number < 0:
        raise NegativeNumberError(
            "Cannot calculate the square root of a negative number"
        )
    else:
        return number**0.5


root(-3)
# Out:
# ---------------------------------------------------------------------------
# NegativeNumberError                       Traceback (most recent call last)
# Cell In[21], line 15
#      11     else:
#      12         return number**0.5
# ---> 15 root(-3)
#
# Cell In[21], line 8, in root(number)
#       6 def root(number):
#       7     if number < 0:
# ----> 8         raise NegativeNumberError(
#       9             "Cannot calculate the square root of a negative number"
#      10         )
#      11     else:
#      12         return number**0.5
#
# NegativeNumberError: Cannot calculate the square root of a negative number
